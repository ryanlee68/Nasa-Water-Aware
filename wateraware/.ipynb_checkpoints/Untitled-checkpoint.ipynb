# %%
import pandas as pd

# %%
df = pd.read_csv('FWS_Species_Data_Explorer.csv')

# %%
print(df)
# Out:
#                              Common Name  \
# 0                         Abbott's booby
# 1                  Acklins ground iguana
# 2                       African elephant
# 3      African slender-snouted crocodile
# 4               African viviparous toads
# ...                                  ...
# 39572                Yuma Ridgway's rail
# 39573                Yuma Ridgway's rail
# 39574                Yuma Ridgway's rail
# 39575        Zanzibar red colobus monkey
# 39576                      Zanzibar suni
#
#                                       Scientific Name  \
# 0                            Papasula (=Sula) abbotti
# 1                             Cyclura rileyi nuchalis
# 2                                  Loxodonta africana
# 3                             Crocodylus cataphractus
# 4                                Nectophrynoides spp.
# ...                                               ...
# 39572                     Rallus obsoletus yumanensis
# ...
